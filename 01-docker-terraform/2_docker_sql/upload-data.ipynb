# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
df = pd.read_csv('yellow_tripdata_2019-01.csv.gz', nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1          1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2          2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3          2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4          2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ..       ...                  ...                   ...              ...
# 95         2  2019-01-01 00:02:06   2019-01-01 00:10:19                2
# 96         2  2019-01-01 00:24:57   2019-01-01 00:35:42                2
# 97         2  2019-01-01 00:46:09   2019-01-01 01:06:46                1
# 98         1  2019-01-01 00:16:07   2019-01-01 00:19:41                1
# 99         1  2019-01-01 00:23:47   2019-01-01 00:39:41                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.50           1                  N           151           239
# 1            2.60           1                  N           239           246
# 2            0.00           1                  N           236           236
# 3            0.00           1                  N           193           193
# 4            0.00           2                  N           193           193
# ..            ...         ...                ...           ...           ...
# 95           2.57           1                  N            45            97
# 96           2.44           1                  N           144           256
# 97           4.18           1                  N            79           263
# 98           1.00           1                  N           140           233
# 99           3.90           1                  N           229           238
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              1          7.0    0.5      0.5        1.65           0.0
# 1              1         14.0    0.5      0.5        1.00           0.0
# 2              1          4.5    0.5      0.5        0.00           0.0
# 3              2          3.5    0.5      0.5        0.00           0.0
# 4              2         52.0    0.0      0.5        0.00           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95             1          9.5    0.5      0.5        2.16           0.0
# 96             2         10.5    0.5      0.5        0.00           0.0
# 97             1         16.0    0.5      0.5        3.46           0.0
# 98             1          5.0    0.5      0.5        1.00           0.0
# 99             1         14.5    0.5      0.5        4.70           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3          9.95                   NaN
# 1                     0.3         16.30                   NaN
# 2                     0.3          5.80                   NaN
# 3                     0.3          7.55                   NaN
# 4                     0.3         55.55                   NaN
# ..                    ...           ...                   ...
# 95                    0.3         12.96                   NaN
# 96                    0.3         11.80                   NaN
# 97                    0.3         20.76                   NaN
# 98                    0.3          7.30                   NaN
# 99                    0.3         20.50                   NaN
#
# [100 rows x 18 columns]

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2019-01.csv.gz', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1             1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2             2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3             2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4             2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...         ...                  ...                   ...              ...
# 99995         2  2019-01-01 13:43:31   2019-01-01 14:02:15                1
# 99996         1  2019-01-01 13:45:41   2019-01-01 13:51:12                4
# 99997         1  2019-01-01 13:52:57   2019-01-01 14:02:20                4
# 99998         2  2019-01-01 13:11:58   2019-01-01 13:16:56                5
# 99999         2  2019-01-01 13:20:35   2019-01-01 13:36:18                5
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               1.50           1                  N           151
# 1               2.60           1                  N           239
# 2               0.00           1                  N           236
# 3               0.00           1                  N           193
# 4               0.00           2                  N           193
# ...              ...         ...                ...           ...
# 99995           4.83           1                  N           234
# 99996           1.10           1                  N           230
# 99997           0.90           1                  N           186
# 99998           1.72           1                  N           107
# 99999           2.01           1                  N           140
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0               239             1          7.0    0.5      0.5        1.65
# 1               246             1         14.0    0.5      0.5        1.00
# 2               236             1          4.5    0.5      0.5        0.00
# 3               193             2          3.5    0.5      0.5        0.00
# 4               193             2         52.0    0.0      0.5        0.00
# ...             ...           ...          ...    ...      ...         ...
# 99995           238             1         17.0    0.0      0.5        3.56
# 99996           186             2          6.0    0.0      0.5        0.00
# 99997           170             2          7.5    0.0      0.5        0.00
# 99998           229             2          7.0    0.0      0.5        0.00
# 99999           161             1         11.5    0.0      0.5        3.08
#
#        tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# 0               0.0                    0.3          9.95                   NaN
# 1               0.0                    0.3         16.30                   NaN
# 2               0.0                    0.3          5.80                   NaN
# 3               0.0                    0.3          7.55                   NaN
# 4               0.0                    0.3         55.55                   NaN
# ...             ...                    ...           ...                   ...
# 99995           0.0                    0.3         21.36                   NaN
# 99996           0.0                    0.3          6.80                   NaN
# 99997           0.0                    0.3          8.30                   NaN
# 99998           0.0                    0.3          7.80                   NaN
# 99999           0.0                    0.3         15.38                   NaN
#
# [100000 rows x 18 columns]

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
##Con esto lo que se hace es que al pasar solo los titulos ejecuta el create statement
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: total: 9.72 s
# Wall time: 18.1 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 21.889 second
# inserted another chunk, took 24.041 second
# inserted another chunk, took 19.123 second
# inserted another chunk, took 20.128 second
# inserted another chunk, took 22.407 second
# inserted another chunk, took 21.616 second
# inserted another chunk, took 20.547 second
# inserted another chunk, took 23.816 second
# inserted another chunk, took 18.592 second
# inserted another chunk, took 18.703 second
# inserted another chunk, took 22.648 second
# inserted another chunk, took 24.237 second
# inserted another chunk, took 20.935 second
# inserted another chunk, took 26.397 second
# inserted another chunk, took 20.789 second
# inserted another chunk, took 18.978 second
# inserted another chunk, took 21.130 second
# inserted another chunk, took 20.000 second
# inserted another chunk, took 24.010 second
# inserted another chunk, took 27.829 second
# inserted another chunk, took 17.475 second
# inserted another chunk, took 18.729 second
# inserted another chunk, took 21.416 second
# inserted another chunk, took 21.419 second
# inserted another chunk, took 23.045 second
# inserted another chunk, took 19.349 second
# inserted another chunk, took 19.827 second
# inserted another chunk, took 23.681 second
# inserted another chunk, took 20.391 second
# inserted another chunk, took 23.317 second
# inserted another chunk, took 24.022 second
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 9
#       6 df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       7 df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
# ----> 9 df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
#      11 t_end = time()
#      13 print('inserted another chunk, took %.3f second' % (t_end - t_start))
#
# File C:\python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File C:\python311\Lib\site-packages\pandas\core\generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File C:\python311\Lib\site-packages\pandas\io\sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File C:\python311\Lib\site-packages\pandas\io\sql.py:1958, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1946 sql_engine = get_engine(engine)
#    1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    (...)
#    1955     dtype=dtype,
#    1956 )
# -> 1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    1961     frame=frame,
#    1962     name=name,
#    1963     index=index,
#    1964     schema=schema,
#    1965     chunksize=chunksize,
#    1966     method=method,
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#    1971 return total_inserted
#
# File C:\python311\Lib\site-packages\pandas\io\sql.py:1498, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1495 from sqlalchemy import exc
#    1497 try:
# -> 1498     return table.insert(chunksize=chunksize, method=method)
#    1499 except exc.StatementError as err:
#    1500     # GH34431
#    1501     # https://stackoverflow.com/a/67358288/6067848
#    1502     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1503     )|inf can not be used with MySQL"""
#
# File C:\python311\Lib\site-packages\pandas\io\sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File C:\python311\Lib\site-packages\pandas\io\sql.py:951, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     939 """
#     940 Execute SQL statement inserting data
#     941
#    (...)
#     948    Each item contains a list of values to be inserted
#     949 """
#     950 data = [dict(zip(keys, row)) for row in data_iter]
# --> 951 result = conn.execute(self.table.insert(), data)
#     952 return result.rowcount
#
# File C:\python311\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File C:\python311\Lib\site-packages\sqlalchemy\sql\elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File C:\python311\Lib\site-packages\sqlalchemy\engine\base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File C:\python311\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840 context.pre_exec()
#    1842 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
#    1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File C:\python311\Lib\site-packages\sqlalchemy\engine\base.py:2030, in Connection._exec_insertmany_context(self, dialect, context)
#    2027 if self._echo:
#    2028     stats = context._get_cache_stats() + " (insertmanyvalues)"
# -> 2030 for imv_batch in dialect._deliver_insertmanyvalues_batches(
#    2031     cursor,
#    2032     str_statement,
#    2033     effective_parameters,
#    2034     generic_setinputsizes,
#    2035     context,
#    2036 ):
#    2037     if imv_batch.processed_setinputsizes:
#    2038         try:
#
# File C:\python311\Lib\site-packages\sqlalchemy\engine\default.py:788, in DefaultDialect._deliver_insertmanyvalues_batches(self, cursor, statement, parameters, generic_setinputsizes, context)
#     785     sort_by_parameter_order = False
#     786     result = None
# --> 788 for imv_batch in compiled._deliver_insertmanyvalues_batches(
#     789     statement,
#     790     parameters,
#     791     generic_setinputsizes,
#     792     batch_size,
#     793     sort_by_parameter_order,
#     794 ):
#     795     yield imv_batch
#     797     if is_returning:
#
# File C:\python311\Lib\site-packages\sqlalchemy\sql\compiler.py:5588, in SQLCompiler._deliver_insertmanyvalues_batches(self, statement, parameters, generic_setinputsizes, batch_size, sort_by_parameter_order)
#    5585 replaced_parameters = base_parameters.copy()
#    5587 for i, param in enumerate(batch):
# -> 5588     fmv = formatted_values_clause.replace(
#    5589         "EXECMANY_INDEX__", str(i)
#    5590     )
#    5591     if imv.embed_values_counter:
#    5592         fmv = fmv.replace("_IMV_VALUES_COUNTER", str(i))
#
# KeyboardInterrupt:

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2022-01-15 23:57:02--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.113.61
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.113.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: 'taxi+_zone_lookup.csv'
#
#      0K .......... ..                                         100%  910K=0.01s
#
# 2022-01-15 23:57:02 (910 KB/s) - 'taxi+_zone_lookup.csv' saved [12322/12322]

# %%
df_zones = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
